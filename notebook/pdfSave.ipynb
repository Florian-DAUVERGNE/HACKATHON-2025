# %%
text = """
 Bulletin d'Information sur les Perturbations Ferroviaires
    Situation globale : Réseau modérément perturbé ce 9 avril 2025
    Plusieurs perturbations localisées affectent actuellement les lignes de transport en commun, avec environ 1 300 000 voyageurs impactés. Les retards sont principalement concentrés sur certaines lignes de tramway, RER et métro.

    Perturbations en Cours
    1. Tramway T1 (Actuelle - Priorité 0)
    De 27 mars à 22 avril 2025 : Le trafic est interrompu entre Gare de Noisy-le-Sec et Escadrille Normandie-Niémen en raison de travaux. Un service de bus de remplacement est mis en place. Stations concernées : Auguste Delaune, Bobigny - Pablo Picasso, Escadrille Normandie-Niemen, Gare de Noisy-le-Sec, Hôtel de Ville de Bobigny, Jean Rostand, La Ferme, Libération, Petit Noisy, Pont de Bondy. Environ 1 272 172 voyageurs impactés.

    3. Métro 4 (Actuelle - Priorité .) 
    "De 16h38 à 19h30, des trains stationnent entre Saint-Sulpice et Strasbourg - Saint-Denis vers Porte de Clignancourt en raison d'un malaise voyageur à Châtelet. Plus d'informations sur le site ratp.fr. Message court : Trains stationnent. Points d'arrêt affectés : Châtelet, Cité, Etienne Marcel, Les Halles, Odéon, Réaumur - Sébastopol, Saint-Germain-des-Prés, Saint-Michel, Saint-Sulpice, Strasbourg - Saint-Denis. Nom : 4. Mode : Metro.

    4. RER E (Actuelle - Priorité 30) 
    De 16h34 à 19h30, le trafic est perturbé de Nanterre-La-Folie vers Chelles - Gournay. Pour plus d'informations sur cette perturbation, consultez le fil Twitter du RER E. Motif: train retenu en atelier de maintenance.. Message court : fortement ralenti. Points d'arrêt affectés : Bondy, Chelles - Gournay, Gagny, Haussmann Saint-Lazare, La Défense, Le Chénay Gagny, Le Raincy - Villemomble - Montfermeil, Magenta, Nanterre-La-Folie, Neuilly Porte Maillot, Noisy-le-Sec, Pantin, Rosa Parks. Nom : E. Mode : RapidTransit.

    Perturbations à Venir
    1. Ligne E (Travaux - 7 avril au 5 mai) 
    De 7 avril au 9 mai sauf jeudi 8 mai, le train NOVY, au départ de Villiers-sur-Marne à 20h49, a pour terminus Paris Est et devient POVE. Il est sans arrêt de Rosa Parks à Paris Est. Ses horaires sont avancés jusqu'à 5 minutes à partir de Nogent-le-Perreux jusqu'au terminus. Les trains NOVY suivant et précédent ont leur desserte inchangée de Villiers-sur-Marne à Nanterre-la-Folie. Les horaires du calculateur d'itinéraire tiennent compte des travaux. Motif: travaux.

    2. Ligne E (Travaux - 9 avril à 10 avril) 
    De 19h30 à 20h30, le train TANU, initialement au départ de Nanterre-la-Folie à 19h34 et à destination de Tournan est avancé de 2 minutes dans toutes les gares du parcours : départ de Nanterre-la-Folie à 19h32. Les horaires du calculateur d'itinéraire tiennent compte des travaux. Motif: travaux.
"""

# %%
from fpdf import FPDF

# Create a PDF instance
pdf = FPDF()
pdf.add_page()
pdf.set_font("Arial", size=9)
# Add a logo at the bottom of the page
pdf.image("SNCF_logo1.png", x=10, y=pdf.h - 30, w=40) 

# Add the text to the PDF
pdf.multi_cell(0, 7, text, border=1, align='L', fill=False)

# Save the PDF to a file
pdf.output("sncfPDF.pdf")
# Out:
# ''

# %%
# Add a logo at the bottom of the page
#pdf.image("sncf-logo.png", x=10, y=pdf.h - 30, w=50)  # Adjust x, y, and w as needed
