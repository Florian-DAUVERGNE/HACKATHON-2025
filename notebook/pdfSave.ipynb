# %%
text = """
Perturbations en cours :

Tramway T1 : En raison de travaux, le trafic est totalement interrompu entre Gare de Noisy-le-Sec et Escadrille Normandie-Niémen jusqu'au lundi 21 avril 2025. Un bus de remplacement est mis en place pour desservir les points d'arrêt Auguste Delaune, Bobigny - Pablo Picasso, Escadrille Normandie-Niemen, Gare de Noisy-le-Sec, Hôtel de Ville de Bobigny, Jean Rostand, La Ferme, Libération, Petit Noisy, Pont de Bondy. Cette perturbation, qualifiée de "bloquante", n'a pas d'impact sur un nombre connu de voyageurs et est confirmée actuellement. La reprise de circulation est prévue pour le lundi 21 avril à 04h30.
Ligne N : Le trafic est interrompu entre Paris Montparnasse et Dreux du lundi au vendredi, de 21h00 à 02h59, jusqu'au 2 mai 2025, sauf le lundi 21 avril et le jeudi 1er mai, en raison de travaux de maintenance. Un service de bus de remplacement est en place, desservant les gares intermédiaires. Cette perturbation, qualifiée de "perturbée", impacte 1171 voyageurs et est signalée comme "significatifs retards". La situation est actuellement en cours/active.
Ligne E : En raison de travaux, le train NOVY au départ de Villiers-sur-Marne à 20h49 a pour terminus Paris Est et devient POVE, sans arrêt de Rosa Parks à Paris Est. Ses horaires sont avancés jusqu'à 5 minutes à partir de Nogent-le-Perreux. Les autres trains entre Villiers-sur-Marne et Nanterre-la-Folie ont des horaires inchangés. Ces travaux se poursuivent jusqu'au vendredi 9 mai, sauf le jeudi 8 mai. Cette perturbation est qualifiée de "perturbée" et affecte 826 voyageurs, entraînant des "significatifs retards". Elle est actuellement en cours/active.

Perturbations à venir :

Métro 14 : Du 3 mars au 15 avril, le trafic sera interrompu les lundis et mardis à partir de 22h00, entre Maison Blanche et Saint-Denis - Pleyel en raison de travaux. Un bus de remplacement est mis en place entre Gare de Lyon et Olympiades. Les points d'arrêt concernés sont Bercy, Bibliothèque François Mitterrand, Châtelet, Cour Saint-Emilion, Gare de Lyon, Madeleine, Mairie de Saint-Ouen, Maison Blanche, Olympiades, Pont Cardinet, Porte de Clichy, Pyramides, Saint-Denis - Pleyel, Saint-Lazare et Saint-Ouen.
Métro 14 : Jusqu'au 29 avril, le trafic est interrompu les lundis et mardis à partir de 22h00, entre Maison Blanche et Saint-Denis - Pleyel en raison de travaux. Un bus de remplacement est mis en place entre Gare de Lyon et Olympiades. Les points d'arrêt concernés sont Bercy, Bibliothèque François Mitterrand, Châtelet, Cour Saint-Emilion, Gare de Lyon, Madeleine, Mairie de Saint-Ouen, Maison Blanche, Olympiades, Pont Cardinet, Porte de Clichy, Pyramides, Saint-Denis - Pleyel, Saint-Lazare et Saint-Ouen.
Ligne N : Le trafic est interrompu entre Paris Montparnasse et Plaisir - Grignon du lundi au vendredi, de 22h00 à 02h59, du 7 avril au 2 mai, sauf le 1er mai, en raison de travaux de maintenance. Un service de bus de remplacement est en place, desservant les gares intermédiaires. Les points d'arrêt concernés sont Chaville Rive Gauche, Clamart, Fontenay-le-Fleury, Gare Montparnasse, Gare de Bellevue, Meudon, Plaisir - Grignon, Plaisir - Les Clayes, Saint-Cyr, Sèvres Rive Gauche, Vanves - Malakoff, Versailles Chantiers, Villepreux - Les Clayes et Viroflay Rive Gauche.
"""

# %%
from fpdf import FPDF

# Create a PDF instance
pdf = FPDF()
pdf.add_page()
pdf.set_font("Arial", size=9)
# Add a logo at the bottom of the page
pdf.image("SNCF_logo1.png", x=10, y=pdf.h - 30, w=40) 

# Add the text to the PDF
pdf.multi_cell(0, 7, text, border=1, align='L', fill=False)

# Save the PDF to a file
pdf.output("my1PDF.pdf")
# Out:
# ''

# %%
# Add a logo at the bottom of the page
pdf.image("sncf-logo.png", x=10, y=pdf.h - 30, w=50)  # Adjust x, y, and w as needed
